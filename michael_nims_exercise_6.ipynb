# %% [markdown]
# ## Section 1: Version control

# %% [markdown]
# ![NIMS_GITHUB_1.JPG](attachment:NIMS_GITHUB_1.JPG)

# %% [markdown]
# #### This is the first stage of the exercise, the notebook has been created and commited to the repository, but does not yet have any content.

# %% [markdown]
# ## Section 2: Chained Conditionals

# %%
x = "Hello!"

if type(x) == int:
    print("This is an integer!")
if type(x) == str:
    print("This is a string!")
if type(x) == float:
    print("This is a float!")
# Out:
# This is a string!
