# %% [markdown]
# ## Section 1: Version control

# %% [markdown]
# ![NIMS_GITHUB_1.JPG](attachment:NIMS_GITHUB_1.JPG)

# %% [markdown]
# #### This is the first stage of the exercise, the notebook has been created and commited to the repository, but does not yet have any content.

# %% [markdown]
# ![NIMS_GITHUB_2.JPG](attachment:NIMS_GITHUB_2.JPG)

# %% [markdown]
# #### This is the second step of the exercise, after i completed the chained conditionals and commited the changes to my repository.

# %% [markdown]
# ## Section 2: Chained Conditionals

# %%
x = "Hello!"

if type(x) == int:
    print("This is an integer!")
if type(x) == str:
    print("This is a string!")
if type(x) == float:
    print("This is a float!")
# Out:
# This is a string!

# %% [markdown]
# ## Section 3: User input and conditionals

# %%
age = 25

if age < 5:
    print("Admission is free!")
if age < 5 and age >12:
    print("Admission is $6")
if age >= 12:
    print("Admission is $12")
# Out:
# Admission is $12
