# %% [markdown]
# ## Section 1: Version control

# %% [markdown]
# #### This is the first step of the exercise, when the file has been created and uploaded to Github but does not yet have any content.

# %% [markdown]
# ![NIMS_GITHUB_1.JPG](attachment:NIMS_GITHUB_1.JPG)

# %% [markdown]
# #### This is the second step of the exercise, after i completed the chained conditionals.

# %% [markdown]
# ![NIMS_GITHUB_2.JPG](attachment:NIMS_GITHUB_2.JPG)

# %% [markdown]
# #### This is the third step of the exercise, after I completed the user input and conditionals section.

# %% [markdown]
# ![NIMS_GITHUB_3.JPG](attachment:NIMS_GITHUB_3.JPG)

# %% [markdown]
# #### This diplays the list of commits, and the comments for each.

# %% [markdown]
# ![NIMS_GITHUB_commits.JPG](attachment:NIMS_GITHUB_commits.JPG)

# %% [markdown]
# ## Section 2: Chained Conditionals

# %%
x = "Hello!"

if type(x) == int:
    print("This is an integer!")
elif type(x) == str:
    print("This is a string!")
elif type(x) == float:
    print("This is a float!")
# Out:
# This is a string!

# %% [markdown]
# ## Section 3: User input and conditionals

# %%
x = int(input("age: "))
age = int(x)
if age < 5:
    print("Admission is free!")
elif age < 5 and age >12:
    print("Admission is $6")
elif age >= 12:
    print("Admission is $12")
# Out:
# age: 25
# Admission is $12

# %%
# I used this section to figure out how to format the code
age = 4

if age < 5:
    print("Admission is free!")
elif age > 5 and age <12:
    print("Admission is $6")
elif age >= 12:
    print("Admission is $12")
# Out:
# Admission is free!
